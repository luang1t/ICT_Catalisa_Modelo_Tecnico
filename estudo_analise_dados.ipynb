# %% [markdown]
# <a href="https://colab.research.google.com/github/luang1t/ICT_Catalisa_Modelo_Tecnico/blob/main/estudo_analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Isso vai me mostrar a lista de arquivos baixados
path = kagglehub.dataset_download("die9origephit/fifa-world-cup-2022-complete-dataset")

print("Path to dataset files:",path)
# Out:
# Using Colab cache for faster access to the 'fifa-world-cup-2022-complete-dataset' dataset.
# Path to dataset files: /kaggle/input/fifa-world-cup-2022-complete-dataset

# %%
import os
# Essa biblioteca vai me mostrar a lista de arquivos baixados

arquivos = os.listdir(path)
# os.listdir() = método que através do caminho passado na celula anterior vai listar todos os arquivos

print(arquivos)
print(os.listdir(path))
# Out:
# ['Fifa_world_cup_matches.csv']
# ['Fifa_world_cup_matches.csv']

# %%
import pandas as pd

arquivo_final = os.path.join(path, 'Fifa_world_cup_matches.csv')
# Vai gerar um novo caminho para o arquivo_final utilizando o join() para juntar o caminho 'die9origephit/fifa-world-cup-2022-complete-dataset' com 'Fifa_world_cup_2022_complete_dataset.csv'

df = pd.read_csv(arquivo_final)
#Aqui conseguimos finalmente ter nosso dataframe criado chamamos 'pd' referenciando a biblioteca e o 'read_csv()' que vai levar o caminho que criamos e armazenamos na variavel 'arquivo_final'



#df.head(4)
#head() método que traz por padrão os primeiros 5, mas passando como parametro algum numero tras ele correspondente

#df.tail(10)
#tail() método que traz por padrão os 5 ultimos, mas passando como parametro algum numero tras ele correspondente

#df.info()
#info() ele traz o "esqueleto" da base de dados
#RangeIndex: 64 entries, 0 to 63 - Significa que a tabela tem 64 linhas
#Data columns: total 88 colums - Numero de colunas
#Dtype: Tipos de dados
#         'object': geralmente é texto - EX: team1(nome do pais) ou date(data)
#         'int64' : Numeros inteiros - EX: number of goals team 1 (ninguém faz meio gol, então é inteiro).
#         'Non-Null Count' : Contador de colunas vazias (buracos)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...
